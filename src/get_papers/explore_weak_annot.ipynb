# %%
import pandas as pd
import json
import os
import logging
from collections import Counter
from datetime import datetime

# %% [markdown]
# grab weak annotation file

# %%
BASE_DIR = "../../data"
WEAK_ANNOTATION_POOL_FILE = os.path.join(BASE_DIR, "weak_annotation_pool.jsonl")


def load_weak_annotations_to_dataframe(file_path: str) -> pd.DataFrame:
    """
    Loads weak annotations from a .jsonl file into a Pandas DataFrame.
    Normalizes the 'weak_annotations' nested field.
    """
    data = []
    if os.path.exists(file_path):
        with open(file_path, 'r', encoding='utf-8') as f:
            for line_num, line in enumerate(f, 1):
                try:
                    data.append(json.loads(line))
                except json.JSONDecodeError:
                    logger.warning(f"Could not parse line in {file_path} at line {line_num}: {line.strip()}")
    else:
        logger.error(f"File not found: {file_path}")
        return pd.DataFrame() # Return an empty DataFrame

    if not data:
        logger.info(f"No data found in {file_path}. Returning empty DataFrame.")
        return pd.DataFrame()

    # Load the main data
    df = pd.DataFrame(data)

    # Normalize the 'weak_annotations' column if it exists
    if 'weak_annotations' in df.columns:
        # json_normalize flattens the nested dictionary into new columns, prefixed by 'weak_annotations.'
        # If 'record_path' is specified, it flattens lists of dictionaries within the nested structure.
        # Here, 'weak_annotations' is a dict, so we just pass it as data to normalize.
        weak_anns_df = pd.json_normalize(df['weak_annotations'])

        # Concatenate the flattened weak_annotations with the original DataFrame,
        # dropping the original 'weak_annotations' column to avoid redundancy.
        df = pd.concat([df.drop('weak_annotations', axis=1), weak_anns_df], axis=1)
    return df

df_annotations = load_weak_annotations_to_dataframe(WEAK_ANNOTATION_POOL_FILE)

# %%
    print("\n--- DataFrame Info ---")
    df_annotations.info()
# Out:
# --- DataFrame Info ---
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3385 entries, 0 to 3384
# Data columns (total 23 columns):
#  #   Column                                       Non-Null Count  Dtype
# ---  ------                                       --------------  -----
#  0   doi                                          3385 non-null   object
#  1   pmid                                         3381 non-null   object
#  2   title                                        3385 non-null   object
#  3   paper_type                                   3385 non-null   object
#  4   relevance_score_llm                          3385 non-null   object
#  5   biological_context                           3385 non-null   object
#  6   data_modalities_used                         3385 non-null   object
#  7   annotation_status                            3385 non-null   object
#  8   llm_query_date                               3385 non-null   object
#  9   llm_model                                    3385 non-null   object
#  10  is_method_paper                              3385 non-null   bool
#  11  is_method_comparison_paper                   3385 non-null   bool
#  12  review_type                                  3385 non-null   object
#  13  methodology_type                             3385 non-null   object
#  14  covered_analysis_steps                       3385 non-null   object
#  15  pipeline_package_name                        3385 non-null   object
#  16  main_goals                                   3385 non-null   object
#  17  data_links_mentioned                         3385 non-null   object
#  18  code_availability.status                     3385 non-null   object
#  19  code_availability.link_in_abstract_or_title  3385 non-null   object
#  20  is_spatial_omics                             1 non-null      object
#  21  is_disease_specific_review                   1 non-null      object
#  22  is_pipeline_paper                            1 non-null      object
# dtypes: bool(2), object(21)
# memory usage: 562.1+ KB

# %%
print("\n--- First 5 rows ---")
df_annotations.head()
# Out:
# --- First 5 rows ---
#                             doi      pmid  \
# 0  10.1371/journal.pcbi.1008887  33872301
# 1    10.1016/j.cell.2020.07.005  32763154
# 2    10.1038/s41467-024-48870-5  38879602
# 3    10.1038/s41592-020-01018-x  33318659
# 4    10.1038/s42003-024-06480-3  38971915
#
#                                                title   paper_type  \
# 0  MAUI (MBI Analysis User Interface)-An image pr...       method
# 1  Coordinated Cellular Neighborhoods Orchestrate...  application
# 2  Deep cell phenotyping and spatial analysis of ...       method
# 3  Cellpose: a generalist algorithm for cellular ...       method
# 4  A point cloud segmentation framework for image...       method
#
#   relevance_score_llm                                 biological_context  \
# 0     highly_relevant                                                N/A
# 1            relevant                                  Colorectal cancer
# 2     highly_relevant                                                N/A
# 3     highly_relevant  Varied cell types and organisms from microscop...
# 4     highly_relevant                                                N/A
#
#                                 data_modalities_used   annotation_status  \
# 0  [MIBI, IMC, multiplexed imaging, spatial prote...  weak_llm_annotated
# 1   [CODEX, multiplexed imaging, spatial proteomics]  weak_llm_annotated
# 2                  [multiplexed imaging, IMC, CODEX]  weak_llm_annotated
# 3                                [microscopy images]  weak_llm_annotated
# 4  [image-based spatial RNA profiling, spatial tr...  weak_llm_annotated
#
#                llm_query_date                              llm_model  ...  \
# 0  2025-06-26T01:48:31.159972  models/gemini-2.5-flash-preview-04-17  ...
# 1  2025-06-26T01:48:56.823109  models/gemini-2.5-flash-preview-04-17  ...
# 2  2025-06-26T01:49:13.426536  models/gemini-2.5-flash-preview-04-17  ...
# 3  2025-06-26T01:49:30.946373  models/gemini-2.5-flash-preview-04-17  ...
# 4  2025-06-26T01:49:49.090237  models/gemini-2.5-flash-preview-04-17  ...
#
#    methodology_type                             covered_analysis_steps  \
# 0          pipeline                         [Preprocessing, Denoising]
# 1               N/A  [Cell Segmentation, Clustering, Spatial Domain...
# 2          pipeline  [Cell Segmentation, Cell-type annotation, Spat...
# 3         algorithm                                [Cell Segmentation]
# 4         framework                                [Cell Segmentation]
#
#   pipeline_package_name                                         main_goals  \
# 0                  MAUI  To present MAUI, a graphical user interface-ba...
# 1                   N/A  To re-engineer CODEX for FFPE tissue microarra...
# 2         TRACERx-PHLEX  Develop a reproducible and user-friendly compu...
# 3              Cellpose  Introduce Cellpose, a generalist deep learning...
# 4                ComSeg  Introduces ComSeg, a point cloud segmentation ...
#
#   data_links_mentioned code_availability.status  \
# 0                   []            Not mentioned
# 1                   []            Not mentioned
# 2                   []            Not mentioned
# 3                   []            Not mentioned
# 4                   []     GitHub link provided
#
#   code_availability.link_in_abstract_or_title is_spatial_omics  \
# 0                                         N/A              NaN
# 1                                         N/A              NaN
# 2                                         N/A              NaN
# 3                                         N/A              NaN
# 4        https://github.com/fish-quant/ComSeg              NaN
#
#   is_disease_specific_review is_pipeline_paper
# 0                        NaN               NaN
# 1                        NaN               NaN
# 2                        NaN               NaN
# 3                        NaN               NaN
# 4                        NaN               NaN
#
# [5 rows x 23 columns]

# %%
print("\n--- Basic Statistics (e.g., relevance and paper type counts) ---")
print("\nRelevance Score Counts:")
print(df_annotations['relevance_score_llm'].value_counts())
# Out:
# --- Basic Statistics (e.g., relevance and paper type counts) ---
#
# Relevance Score Counts:
# relevance_score_llm
# relevant           1695
# highly_relevant     899
# low_relevance       520
# irrelevant          271
# Name: count, dtype: int64

# %%
print("\nPaper Type Counts:")
print(df_annotations['paper_type'].value_counts())
# Out:
# Paper Type Counts:
# paper_type
# application          1505
# method               1266
# review                472
# other                  88
# method_comparison      54
# Name: count, dtype: int64

# %% [markdown]
# Paper types are divided in several types. Application, Methds, Review (can be methods or application), Method comparison.
#
# Lets start with the application papers.

# %% [markdown]
# ***Application papers***

# %%
# Filter the DataFrame for 'application' papers
application_papers_df = df_annotations[df_annotations['paper_type'] == 'application'].copy()

print(f"\n--- Statistics for Application Papers ---")
print(f"Total application papers found: {len(application_papers_df)}")

application_papers_df.head()
# Out:
# --- Statistics for Application Papers ---
# Total application papers found: 1505
#                              doi      pmid  \
# 1     10.1016/j.cell.2020.07.005  32763154
# 49    10.1016/j.cell.2021.12.023  35063072
# 59  10.1126/scitranslmed.adq3852  40560997
# 60  10.1097/HEP.0000000000001432  40560681
# 61     10.3390/proteomes13020017  40559990
#
#                                                 title   paper_type  \
# 1   Coordinated Cellular Neighborhoods Orchestrate...  application
# 49  Transition to invasive breast cancer is associ...  application
# 59  Podocyte YAP and TAZ hyperactivation drives gl...  application
# 60  Multimodal transcriptomics identifies metallot...  application
# 61  Integrative Spatial Proteomics and Single-Cell...  application
#
#    relevance_score_llm                                 biological_context  \
# 1             relevant                                  Colorectal cancer
# 49            relevant            Breast cancer progression (DCIS to IBC)
# 59       low_relevance  Human kidney diseases (collapsing glomerulopat...
# 60       low_relevance   Primary sclerosing cholangitis and liver disease
# 61       low_relevance                 Rheumatoid Arthritis (RA) synovium
#
#                                  data_modalities_used   annotation_status  \
# 1    [CODEX, multiplexed imaging, spatial proteomics]  weak_llm_annotated
# 49    [MIBI, spatial proteomics, multiplexed imaging]  weak_llm_annotated
# 59          [spatial transcriptomics, immunostaining]  weak_llm_annotated
# 60               [spatial transcriptomics, snRNA-seq]  weak_llm_annotated
# 61  [spatial proteomics, scRNA-seq, mass spectrome...  weak_llm_annotated
#
#                 llm_query_date                              llm_model  ...  \
# 1   2025-06-26T01:48:56.823109  models/gemini-2.5-flash-preview-04-17  ...
# 49  2025-06-26T02:06:30.329631  models/gemini-2.5-flash-preview-04-17  ...
# 59  2025-06-26T02:08:32.323956  models/gemini-2.5-flash-preview-04-17  ...
# 60  2025-06-26T02:08:42.172942  models/gemini-2.5-flash-preview-04-17  ...
# 61  2025-06-26T02:08:52.921783  models/gemini-2.5-flash-preview-04-17  ...
#
#     methodology_type                             covered_analysis_steps  \
# 1                N/A  [Cell Segmentation, Clustering, Spatial Domain...
# 49               N/A     [Cell Segmentation, Clustering, Morphometrics]
# 59               N/A                                                 []
# 60               N/A                                                 []
# 61               N/A      [Integration with other omics, Deconvolution]
#
#    pipeline_package_name                                         main_goals  \
# 1                    N/A  To re-engineer CODEX for FFPE tissue microarra...
# 49                   N/A  To understand the changes in the tumor microen...
# 59                   N/A  To identify common molecular drivers of glomer...
# 60                   N/A  To localize potential disease pathways to spec...
# 61                   N/A  To understand molecular heterogeneity in Rheum...
#
#    data_links_mentioned code_availability.status  \
# 1                    []            Not mentioned
# 49                   []            Not mentioned
# 59                   []            Not mentioned
# 60                   []            Not mentioned
# 61                   []            Not mentioned
#
#    code_availability.link_in_abstract_or_title is_spatial_omics  \
# 1                                          N/A              NaN
# 49                                         N/A              NaN
# 59                                         N/A              NaN
# 60                                         N/A              NaN
# 61                                         N/A              NaN
#
#    is_disease_specific_review is_pipeline_paper
# 1                         NaN               NaN
# 49                        NaN               NaN
# 59                        NaN               NaN
# 60                        NaN               NaN
# 61                        NaN               NaN
#
# [5 rows x 23 columns]

# %%
print("\n--- Relevance Score Breakdown for Application Papers ---")

# Get both absolute counts and normalized percentages
relevance_counts_app = application_papers_df['relevance_score_llm'].value_counts()
relevance_percentages_app = application_papers_df['relevance_score_llm'].value_counts(normalize=True) * 100

# Iterate through the index (relevance scores) of the counts Series
for score in relevance_counts_app.index:
    count = relevance_counts_app[score]
    percentage = relevance_percentages_app[score]
    print(f"- {score}: {percentage:.2f}% ({count} papers)")
# Out:
# --- Relevance Score Breakdown for Application Papers ---
# - relevant: 75.02% (1129 papers)
# - low_relevance: 21.59% (325 papers)
# - irrelevant: 3.39% (51 papers)

# %%
print("\n--- Data Modalities Used Counts for Application Papers ---")
# This column contains lists, so we need to use Counter to count individual modalities
application_modalities_counter = Counter()

# Iterate through the 'data_modalities_used' column, handling potential missing values (NaN)
# and ensuring the content is actually a list before updating the counter.
if 'data_modalities_used' in application_papers_df.columns:
    for modalities_list in application_papers_df['data_modalities_used'].dropna():
        if isinstance(modalities_list, list):
            application_modalities_counter.update(modalities_list)

    if application_modalities_counter:
        print("Counts of each data modality used in Application Papers:")
        # Display all counts, or use .most_common(N) to show only top N
        for modality, count in application_modalities_counter.most_common():
            print(f"- {modality}: {count}")
    else:
        print("No data modalities found or processed for application papers.")
else:
    print("'data_modalities_used' column not found in application papers DataFrame.")
# Out:
# --- Data Modalities Used Counts for Application Papers ---
# Counts of each data modality used in Application Papers:
# - spatial transcriptomics: 1087
# - histology images: 295
# - single-cell RNA sequencing: 211
# - snRNA-seq: 117
# - spatial proteomics: 98
# - scRNA-seq: 97
# - single-cell transcriptomics: 95
# - sequencing: 81
# - immunohistochemistry: 78
# - spatial metabolomics: 51
# - bulk RNA-seq: 45
# - bulk RNA sequencing: 34
# - immunofluorescence: 32
# - proteomics: 32
# - multiplexed imaging: 31
# - Visium: 30
# - single-cell sequencing: 30
# - flow cytometry: 26
# - bulk transcriptomics: 23
# - single-cell RNA-sequencing: 23
# - transcriptomics: 22
# - single-cell analysis: 22
# - single-cell RNA-seq: 18
# - multiplex immunofluorescence: 18
# - RNA sequencing: 17
# - RNA-seq: 15
# - HE-stained images: 15
# - metabolomics: 15
# - multiplex immunohistochemistry: 15
# - mass spectrometry imaging: 15
# - single-nucleus RNA sequencing: 13
# - immunofluorescence staining: 12
# - bulk RNA-sequencing: 12
# - IHC: 11
# - mass spectrometry: 10
# - in vitro experiments: 10
# - single-cell spatial transcriptomics: 10
# - gene expression profiling: 10
# - single-cell RNA sequencing (scRNA-seq): 10
# - immunostaining: 9
# - RT-qPCR: 9
# - MERFISH: 9
# - Stereo-seq: 9
# - imaging mass cytometry: 9
# - Xenium: 8
# - chromatin accessibility: 8
# - whole-genome sequencing: 8
# - digital spatial profiling: 8
# - Immunohistochemistry: 8
# - Western blot: 8
# - ATAC-seq: 7
# - multiplexed immunofluorescence: 7
# - single-cell: 7
# - in situ hybridization: 6
# - IF: 6
# - ELISA: 6
# - bulk transcriptome: 6
# - spatial transcriptome: 6
# - in vivo experiments: 6
# - RNA-Seq: 6
# - Visium spatial transcriptomics: 6
# - single cell RNA sequencing: 6
# - RNA-sequencing: 6
# - CODEX: 5
# - Western blotting: 5
# - single cell transcriptomics: 5
# - RNAscope: 5
# - single cell RNA-sequencing: 5
# - histopathology: 5
# - immunohistochemical staining: 5
# - electron microscopy: 5
# - whole-exome sequencing: 5
# - gene expression: 5
# - MALDI-MSI: 5
# - transcriptome: 5
# - single-nucleus transcriptomics: 5
# - Spatial transcriptomics: 5
# - mIHC: 5
# - MRI: 5
# - transmission electron microscopy: 4
# - multiplex immunofluorescence (mIF): 4
# - immunohistochemistry (IHC): 4
# - spatial transcriptomic data: 4
# - multi-omics: 4
# - TCGA: 4
# - single-cell multiomics: 4
# - spatial transcriptomics (ST): 4
# - snATAC-seq: 4
# - transcriptomic data: 4
# - phosphoproteomics: 4
# - in vivo models: 4
# - transcriptomic: 4
# - spatial transcriptome sequencing: 4
# - proteomic analysis: 4
# - spatial RNA sequencing: 4
# - multiplex imaging: 4
# - multiomics: 4
# - DESI-MSI: 4
# - spatial omics: 4
# - IMC: 4
# - AFADESI-MSI: 4
# - biochemical assays: 3
# - scRNAseq: 3
# - Imaging Mass Cytometry: 3
# - Multiomics: 3
# - RNAseq: 3
# - western blotting: 3
# - quantitative real-time PCR: 3
# - single-cell transcriptome: 3
# - clinical samples: 3
# - qRT-PCR: 3
# - immunohistochemical analysis: 3
# - single-nucleus sequencing: 3
# - spatial transcriptomic analysis: 3
# - mRNA: 3
# - whole exome sequencing: 3
# - Immunofluorescence staining: 3
# - fMRI: 3
# - untargeted metabolomics: 3
# - proteome: 3
# - spectral flow cytometry: 3
# - TCR sequencing: 3
# - CODEX spatial proteomics: 3
# - in situ sequencing: 3
# - gene expression analysis: 3
# - single-nucleus RNA sequencing (snRNA-seq): 3
# - in vitro models: 3
# - GEO: 3
# - metabolomic: 3
# - laser capture microdissection: 3
# - DNA methylation: 3
# - Metabolomics: 3
# - multiplexed immunohistochemistry: 3
# - qPCR: 3
# - lipidomics: 3
# - TCGA data: 3
# - T-cell receptor sequencing: 3
# - bulk sequencing: 3
# - in vitro assays: 3
# - Visium HD: 3
# - bulk proteomics: 3
# - Histology images: 3
# - bulk metabolomics: 3
# - plasma metabolomics: 3
# - light-sheet microscopy: 3
# - bulk RNAseq: 3
# - tissue microarrays: 3
# - imaging: 3
# - single cell sequencing: 3
# - LC-MS: 3
# - single-cell RNA-Seq: 3
# - organoids: 3
# - genomics: 3
# - digital spatial transcriptomics: 3
# - niche analysis: 3
# - Mass Spectrometry Imaging: 3
# - scATAC-seq: 3
# - single-nuclei RNA-sequencing: 3
# - mouse model: 3
# - single-cell atlas: 2
# - epigenomics: 2
# - genetics: 2
# - T cell receptor sequencing: 2
# - imaging-based spatial transcriptomics: 2
# - spatial profiling: 2
# - co-immunoprecipitation: 2
# - chromatin immunoprecipitation: 2
# - spatially resolved transcriptomics: 2
# - animal experiments: 2
# - GeoMx spatial transcriptomics: 2
# - histological analysis: 2
# - keratinocytes: 2
# - scStereo-seq: 2
# - in vivo lineage tracing: 2
# - spatial transcriptomics sequencing: 2
# - clinical specimens: 2
# - cryosections: 2
# - transcriptome profiling: 2
# - spatial immunoreceptor profiling: 2
# - Xenium in situ transcriptomics: 2
# - co-culture assays: 2
# - multiplexed immunofluorescence staining: 2
# - positron-emission tomography: 2
# - T-cell clonotype analysis: 2
# - MHC Class I immunopeptidomics: 2
# - liquid chromatography-mass spectrometry: 2
# - Imaging mass cytometry: 2
# - lymph nodes: 2
# - transcriptome data: 2
# - single-cell data: 2
# - 16S rRNA sequencing: 2
# - spatially-resolved transcriptomics: 2
# - LC-MS/MS: 2
# - multiscale 3D imaging: 2
# - Stereo-seq spatial transcriptomics: 2
# - immunolocalization: 2
# - genome sequencing: 2
# - time-of-flight mass cytometry: 2
# - immunotherapy datasets: 2
# - spatial lipidomics: 2
# - 10x Visium: 2
# - resting-state fMRI: 2
# - mass spectrometry imaging (MSI): 2
# - extracellular vesicles: 2
# - single cell RNA-seq: 2
# - mRNA expression: 2
# - protein expression: 2
# - single-nuclei RNA sequencing: 2
# - genomic data: 2
# - spatial transcriptomic sequencing: 2
# - serum metabolomics: 2
# - imaging techniques: 2
# - single-cell transcriptomes: 2
# - Mass spectrometry imaging (MSI): 2
# - Diffusion Magnetic Resonance Imaging: 2
# - Diffusion Kurtosis Imaging: 2
# - organoid explant systems: 2
# - gene expression profiles: 2
# - patient samples: 2
# - single-nucleus RNA-seq: 2
# - single-cell RNA: 2
# - MALDI mass spectrometry imaging: 2
# - high-resolution spatial transcriptomics: 2
# - Immunofluorescent staining: 2
# - Transmission electron microscopy: 2
# - quantitative PCR: 2
# - pathological image analysis: 2
# - FISH: 2
# - mass cytometry: 2
# - Single-cell RNA sequencing: 2
# - Hyperspectral Imaging: 2
# - microscopy: 2
# - patient-derived xenograft models: 2
# - live imaging: 2
# - TCR-seq: 2
# - RT-PCR: 2
# - CyTOF: 2
# - high-resolution multiplex imaging: 2
# - lineage tracing: 2
# - Single-Cell RNA sequencing: 2
# - single-cell proteomics: 2
# - RNA tomography: 2
# - single-cell omics: 2
# - Histology: 2
# - Visium CytAssist spatial transcriptomics: 2
# - multiple immunofluorescence: 2
# - organotypic culture: 2
# - fluorescence: 2
# - cell line: 2
# - single-molecule fluorescence in situ hybridization: 2
# - ChIP-seq: 2
# - immunoblotting: 2
# - DNA methylation profiling: 2
# - immunolabeling: 2
# - environmental data: 2
# - single nucleus RNA-sequencing: 2
# - ATAC sequencing: 2
# - ATAC-Seq: 2
# - ISS: 2
# - DESI: 2
# - intravital imaging: 2
# - laser microdissection: 2
# - MIBI: 1
# - Laser Capture Microdissection: 1
# - morphometry: 1
# - LIBS: 1
# - EDX: 1
# - PET/CT: 1
# - MRS: 1
# - spatial multiomics: 1
# - pan-cancer expression profiling: 1
# - western blot analysis: 1
# - targeted metabolomics: 1
# - RNA in situ hybridisation (RISH): 1
# - Single-cell Analysis: 1
# - CT scans: 1
# - radiomics: 1
# - serology: 1
# - GeoMx spatial analysis: 1
# - mixed lymphocyte reaction-based clonal "fingerprinting": 1
# - TCR clonotyping: 1
# - single-cell RNA/TCR sequencing: 1
# - MERSCOPE: 1
# - chromatin accessibility sequencing: 1
# - Pollination niche analysis: 1
# - pollinator color perception studies: 1
# - reproductive output assessments: 1
# - molecular phylogenetics: 1
# - gene flow analyses: 1
# - species distribution modeling: 1
# - spatial-omics: 1
# - ChIP: 1
# - spatial epigenome: 1
# - luciferase gene reporter assays: 1
# - lentiviral transfection: 1
# - cell co-culture experiments: 1
# - recombinant protein rescue experiments: 1
# - knockout mice: 1
# - Cre-loxP system mice: 1
# - gene regulation assays: 1
# - formalin-fixed paraffin-embedded tumors: 1
# - multispectral immunohistochemistry: 1
# - NanoString spatial transcriptomics: 1
# - peak oxygen uptake (V̇O₂peak): 1
# - mouse brain: 1
# - SNARE-seq2: 1
# - chromatin conformation capture (Hi-C): 1
# - single-cell spatial transcriptomics (Xenium): 1
# - multiplex immunohistochemistry staining: 1
# - Quantseq Bulk RNA sequencing: 1
# - Nanostring GeoMX spatial transcriptomics: 1
# - protein-protein interaction network: 1
# - UPLC-MS/MS: 1
# - lymphocyte subset tests: 1
# - mIF: 1
# - chromatin immunoprecipitation sequencing: 1
# - xenograft models: 1
# - Landsat 9 satellite data: 1
# - immunohistology: 1
# - stRNA-seq: 1
# - multiplexed immunofluorescence imaging: 1
# - micro-CT imaging: 1
# - transcriptomic methods: 1
# - Immunohistochemical analysis: 1
# - in vitro studies: 1
# - primary human keratinocytes: 1
# - skin tissue samples: 1
# - pigmented living skin equivalent (pLSE) model: 1
# - bulk genomics: 1
# - ceRNA network analysis: 1
# - QSAR modeling: 1
# - multispectral immune cell immunofluorescence (IF): 1
# - miRNA sequencing data: 1
# - formalin-fixed paraffin-embedded kidney biopsy specimens: 1
# - genetic alteration: 1
# - copy number alteration: 1
# - immune-related features: 1
# - single-cell transcriptomic data: 1
# - CGGA: 1
# - 10x Genomics Visium: 1
# - tissue microarray: 1
# - RNA in situ: 1
# - Stereo-seq transcriptomics: 1
# - in vitro epidermal equivalents: 1
# - surgical tissue specimens: 1
# - multiplexed protein assays: 1
# - Bulk RNA sequencing (RNA-seq): 1
# - single-cell RNA sequencing analysis: 1
# - plasma proteome analysis: 1
# - protein: 1
# - bulk RNA-seq data: 1
# - spatial immunofluorescence: 1
# - mass cytometry imaging: 1
# - formalinfixedparaffinembedded tissues: 1
# - Visium Spatial Transcriptomics: 1
# - whole transcriptome sequencing: 1
# - MIBI-TOF (Multiplexed Ion Beam Imaging Time-of-Flight Spectrometry): 1
# - clinical parameters: 1
# - mutational profiling: 1
# - TCGA-ovarian serous cystadenocarcinoma (OV): 1
# - patient-derived explant culture: 1
# - multiplex cytokine profiling: 1
# - pan-cancer single-cell RNA sequencing: 1
# - real-world immunotherapy data: 1
# - patient-derived GBM organoids: 1
# - intracranial orthotopic GBM model: 1
# - PacBio HiFi long-read sequencing: 1
# - enzymatic functional assays: 1
# - single-cell resolution spatial transcriptomics: 1
# - resting-state MRI: 1
# - anatomical MRI: 1
# - single-cell transcriptomics (scRNA-seq): 1
# - hematoxylin-eosin (H&E)-stained images: 1
# - mouse model of bilateral renal ischemia-reperfusion injury: 1
# - multiple immunofluorescence staining: 1
# - bulk data analysis: 1
# - ex vivo experiments: 1
# - real-time quantitative polymerase chain reaction: 1
# - quantitative genetics: 1
# - comparative genomics: 1
# - functional genomics: 1
# - serum proteomic profiling: 1
# - single-cell MultiOmics: 1
# - zebrafish embryos: 1
# - spatial transcriptome analysis: 1
# - viral tracing: 1
# - neural circuit approaches: 1
# - 10X Visium spatial transcriptomics: 1
# - antigen receptor sequencing: 1
# - GeoMx Whole Human Transcriptome Atlas: 1
# - sc/snRNA-seq data: 1
# - single-cell RNAseq: 1
# - CITE-seq: 1
# - sn-RNA-seq: 1
# - quantitative immunohistochemistry: 1
# - resting-state functional MRI: 1
# - diffusion-weighted images: 1
# - cytometry by time-of-flight analysis: 1
# - high-definition spatial transcriptomics: 1
# - single-cell/single-nucleus RNA sequencing: 1
# - preclinical mouse models: 1
# - in utero electroporation: 1
# - bioclimatological data: 1
# - postmortem tissue analysis: 1
# - transcriptomic profiles: 1
# - transwell assay: 1
# - scratch wound healing assay: 1
# - in vitro oxygen-glucose deprivation/reperfusion: 1
# - DNA methylome: 1
# - cerebral organoid model: 1
# - 4D-DIA quantitative proteomics: 1
# - spatial mass spectrometry imaging: 1
# - stereotactic needle core biopsies: 1
# - mouse brain sections: 1
# - patient-derived organoid models: 1
# - clinical sample analyses: 1
# - fluorescence microscopy: 1
# - in vitro cell culture: 1
# - mouse dorsal root ganglia (DRG): 1
# - primary DRG cultures: 1
# - hind paw skins: 1
# - human DRG: 1
# - quantitative mass spectrometry: 1
# - cell fractionation: 1
# - spatial transcriptomic profiling: 1
# - immunotherapy: 1
# - MALDI-MS: 1
# - CRISPR/cas9 technology: 1
# - small interfering RNAs: 1
# - pharmacological inhibition: 1
# - in situ imaging: 1
# - Genome-Wide Association Study (GWAS) summary statistics: 1
# - RNA in-situ hybridization: 1
# - FFPE samples: 1
# - histologic types: 1
# - protein immunofluorescence: 1
# - cocultures: 1
# - syngeneic cancer mouse models: 1
# - single-cell transcriptomic profiling: 1
# - slice electrophysiology: 1
# - optogenetics: 1
# - pharmacological approaches: 1
# - RNA FISH: 1
# - mass-spectrometry-imaging: 1
# - biochemical indexes: 1
# - Fourier Transform Mid-Infrared Spectroscopy: 1
# - bulk RNA-seq analysis: 1
# - methylation profiling: 1
# - siRNA transfection: 1
# - luciferase reporter assay: 1
# - single-cell transcriptomes (scRNA-seq): 1
# - tube formation assay: 1
# - fecal metabolomics: 1
# - brain spatial metabolomics: 1
# - behavioral tests: 1
# - methylation analysis: 1
# - immune infiltration assays: 1
# - multiplex immunohistochemistry (mIHC): 1
# - mass cytometry (CyTOF): 1
# - bulk data: 1
# - TCR clonotype analyses: 1
# - cancer cell lines: 1
# - electrospray ionization: 1
# - multi-dimensional transcriptomic: 1
# - CGGA database analysis: 1
# - Nanostring CosMx: 1
# - spatial RNA-Seq: 1
# - histological techniques: 1
# - surface plasmon resonance: 1
# - peptide-protein interaction 3D modeling: 1
# - Quantibrite PE beads in PBMCs: 1
# - Real-time PCR (RT-PCR): 1
# - quantitative MRI: 1
# - CRISPR knockin: 1
# - TurboID-based proximity labeling: 1
# - cystic fluid metabolomics: 1
# - tissue metabolomics: 1
# - cell line metabolomics: 1
# - Standard RNA sequencing: 1
# - single nucleus-RNA sequencing: 1
# - synovial samples: 1
# - X-ray fluorescence microscopy: 1
# - bulk-RNA sequencing: 1
# - Nanostring GeoMx: 1
# - single-molecule imaging: 1
# - circulating plasma protein markers: 1
# - urine studies: 1
# - ultrasounds: 1
# - tissue histopathology: 1
# - serial echocardiography: 1
# - paraffin embedded nodules: 1
# - CD3 morphology markers: 1
# - CD4 morphology markers: 1
# - CD30 morphology markers: 1
# - re-sequencing: 1
# - glycomics: 1
# - UPLC-MS: 1
# - H&E staining: 1
# - Masson trichrome staining: 1
# - plasma analysis: 1
# - DNA methylome profiling: 1
# - organoid models: 1
# - metabolic flux analysis: 1
# - multi-species models: 1
# - tissue microarrays (TMAs): 1
# - cell line (CAL27): 1
# - mouse xenografts: 1
# - cell-based assays: 1
# - orthotopic xenografts: 1
# - transcriptomic analysis: 1
# - in-mouse orthotopic transplantation: 1
# - clinicogenomic data: 1
# - human retinal organoids: 1
# - rd10 mouse model of retinitis pigmentosa: 1
# - PCR: 1
# - epigenetics methods: 1
# - bulk lipidomics: 1
# - in vitro cell proliferation assays: 1
# - in vivo tumor regression models: 1
# - patient-derived xenograft (PDX) mouse model: 1
# - proximity proteomics: 1
# - biotinylation by antibody recognition (BAR): 1
# - secretome analysis: 1
# - 18F-fluorodeoxyglucose positron emission tomography (PET): 1
# - high-fat diet model: 1
# - post mortem tissue: 1
# - hippocampal spatial transcriptomics: 1
# - hyperspectral imaging: 1
# - single-cell ATAC sequencing: 1
# - spatial RNA analyses: 1
# - GTEx database: 1
# - single-nuclei sequencing: 1
# - multicolor fluorescence staining: 1
# - mutation/copy number data: 1
# - immunofluorescence (IF): 1
# - in vivo lineage tracing mouse model: 1
# - plasma expression quantitative trait loci (eQTL) data: 1
# - Genome-Wide Association Studies (GWAS) summary statistics: 1
# - RNA-seq (bulk, single-cell, and spatial transcriptomics): 1
# - UK Biobank data: 1
# - RAD-seq: 1
# - hepatic spatial metabolomics: 1
# - UPLC-Q-TOF/MS: 1
# - mRNA quantification: 1
# - cortical AD dataset: 1
# - in vivo assays: 1
# - RNA immunoprecipitation: 1
# - pull-down assays: 1
# - in vitro functional analyses: 1
# - skin organoids: 1
# - in vivo functional perturbations: 1
# - public single-cell transcriptomic data sets: 1
# - host transcriptome: 1
# - bacterial transcriptome: 1
# - human LUAD samples: 1
# - dietary intervention: 1
# - genetic model: 1
# - metabolites: 1
# - hormone-induced decidualization: 1
# - genomic: 1
# - protein expressions: 1
# - transcriptomic reference human breast cancer (BC) datasets: 1
# - single-cell whole-genome sequencing: 1
# - multi-region sequencing: 1
# - 3D spatial transcriptomics: 1
# - frozen CD surgical tissue sections: 1
# - ileal CD mucosa: 1
# - air-flow-assisted desorption electrospray ionization mass spectrometry imaging (AFADESI-MSI): 1
# - matrix-assisted laser desorption ionization mass spectrometry imaging (MALDI-MSI): 1
# - Nissl staining: 1
# - multiplex IHC: 1
# - high-resolution ultrahigh-performance liquid chromatography tandem mass spectrometry (HR-UHPLC-MS/MS): 1
# - matrix-assisted laser desorption/ionization mass spectrometry imaging (MALDI-MSI): 1
# - copy number variation (CNV): 1
# - scRNA seq: 1
# - in vitro ACM models: 1
# - explanted hearts: 1
# - Xenium In Situ mRNA spatial profiling: 1
# - RNAscope Multiplex assays: 1
# - plasma proteomic analysis (Olink): 1
# - snMultiomes: 1
# - single nucleus multiomics: 1
# - targeted bile acid metabolomics: 1
# - mouse organoids: 1
# - human organoids: 1
# - digital spatial mRNA profiling: 1
# - lung biopsies: 1
# - alveolar macrophage transcriptomics: 1
# - district level data on maternal deaths: 1
# - single-cell spatial sequencing: 1
# - CD34+ cells: 1
# - White Matter Tractography: 1
# - skin biopsies: 1
# - peripheral blood: 1
# - cellular transcriptomics: 1
# - cell-free transcriptomics: 1
# - plasma samples: 1
# - inbred C57BL mice: 1
# - transcriptomics data: 1
# - Digital Spatial Profiling: 1
# - C4d staining: 1
# - FFPE tissues: 1
# - Immunofluorescence (IF): 1
# - single-cell studies: 1
# - behavioral assays: 1
# - histochemical staining: 1
# - organoid: 1
# - T cell co-culture systems: 1
# - stable isotope labeling: 1
# - hyperspectral confocal microscopy: 1
# - morphological features: 1
# - quantitative real-time polymerase chain reaction (qRT-PCR): 1
# - Ex vivo culture: 1
# - murine models: 1
# - pbacBarcode: 1
# - UPLC-QTOFMS: 1
# - molecular networking: 1
# - birthdating analysis: 1
# - nanostring digital spatial profiling (DSP): 1
# - in situ proximity ligation assay (isPLA): 1
# - cell assays: 1
# - protein details: 1
# - spatial gene expressions: 1
# - Immunohistology: 1
# - Calcium imaging: 1
# - Multiplexed imaging: 1
# - Optogenetics: 1
# - nuclei transcriptomic datasets: 1
# - immunohistochemistry (implied by cell markers and regions of interest): 1
# - patient keratinocytes: 1
# - quantitative cytokine profiling: 1
# - MALDI MSI: 1
# - kinase arrays: 1
# - 3D coculture spheroid model: 1
# - magnetic resonance imaging: 1
# - pulmonary function testing: 1
# - whole genome bisulfite sequencing: 1
# - spatial RNAseq: 1
# - bronchial alveolar lavage: 1
# - multispectral fluorescence imaging: 1
# - single-cell transcriptomic atlas: 1
# - quantitative metabolomics: 1
# - multi-parameter imaging: 1
# - histopathology images: 1
# - immunofluorescence analysis: 1
# - nanoparticle tracking analysis: 1
# - western blot: 1
# - fluorescently labeled progenitor cells: 1
# - human liver explants: 1
# - Hormone detection: 1
# - immunopeptidomics: 1
# - cytokine production analysis: 1
# - tetramer-positive population analysis: 1
# - whole transcriptome assay: 1
# - single cell RNA-seq (scRNA-seq): 1
# - lipid metabolomics: 1
# - Whole Genome Sequencing: 1
# - nighttime light data: 1
# - CO2 emission data: 1
# - epigenomic sequencing: 1
# - 10x Genomics: 1
# - single-cell spatial omics: 1
# - single-cell spatial analysis: 1
# - single cell spatial transcriptomics: 1
# - fNIRS: 1
# - polychromatic flow cytometry: 1
# - single-cell tissue imaging: 1
# - multiplexed imaging mass cytometry: 1
# - microarray: 1
# - Stereo-seq technology: 1
# - Bulk-RNA-Seq: 1
# - two-photon calcium imaging: 1
# - Matrix-Assisted Laser Desorption/Ionization Mass Spectrometry Imaging (MALDI-MSI): 1
# - immunohistochemical co-staining: 1
# - bulk tissue gene expression data: 1
# - Colposcopy: 1
# - multiplexed in situ staining: 1
# - matrix-assisted laser desorption mass spectrometry imaging: 1
# - Satellite imagery: 1
# - Sentinel-1: 1
# - Sentinel-2: 1
# - clinical sample analysis: 1
# - single-cell multi-omics: 1
# - fluorescent labeling: 1
# - high-plex imaging: 1
# - bulk-seq: 1
# - gene data: 1
# - CosMx Spatial Molecular Imaging (SMI): 1
# - Plant Leaves: 1
# - confocal images: 1
# - 3D reconstruction: 1
# - UHPLC-MS/MS: 1
# - immune histochemistry: 1
# - population dataset: 1
# - single-cell mRNA-seq: 1
# - EEG: 1
# - immunohistochemical assessment: 1
# - whole-exome-sequencing: 1
# - in-situ sequencing: 1
# - digital image analysis: 1
# - bulk gene expression: 1
# - multiparameter immunofluorescence: 1
# - time-series transcriptome data: 1
# - DNA methylomics: 1
# - tissue staining: 1
# - TEM: 1
# - Immunoglobulin G: 1
# - smFISH: 1
# - Terahertz Spectral Imaging: 1
# - Terahertz Spectroscopy: 1
# - Terahertz Imaging: 1
# - DNA/RNA assays: 1
# - high-resolution mass spectrometry: 1
# - single-nucleus analysis: 1
# - immunofluorescence assay: 1
# - geospatial distribution data: 1
# - climate factors: 1
# - soil factors: 1
# - topography factors: 1
# - immunocytochemistry: 1
# - RNAScope: 1
# - PET: 1
# - DNA LOH: 1
# - PD-L1: 1
# - TMB: 1
# - TCR repertoire: 1
# - TILs populations: 1
# - spatially resolved metabolomics: 1
# - tissue biopsy analysis: 1
# - Sentinel-1 data: 1
# - field data: 1
# - multiplex immunohistochemistry (IHC): 1
# - Single-cell transcriptome: 1
# - spatial metabolome: 1
# - multi-omics integration: 1
# - RNA-FISH: 1
# - BCR profiling: 1
# - multi-modal spatial profiling: 1
# - dual-immunofluorescence staining: 1
# - biochemical assessment: 1
# - spatial molecular imaging: 1
# - Single-nucleus transcriptomics: 1
# - MeRIP-seq: 1
# - micro-computed tomography (μCT): 1
# - bioluminescence imaging (BLI): 1
# - high parameter immunophenotyping: 1
# - bulk transcriptome data: 1
# - Single-cell sequencing: 1
# - hematoxylin-eosin (HE): 1
# - UV-vis spectroscopy: 1
# - biochemistry: 1
# - climate data: 1
# - long-term in-vivo imaging: 1
# - p-ERK staining: 1
# - tumor biopsies: 1
# - Spatial metabolomics: 1
# - MALDI Mass Spectrometry Imaging: 1
# - spatial multiplexed analysis: 1
# - 10X multiome data: 1
# - iPSC-derived microglia-like cells: 1
# - spatial isoform transcriptomics: 1
# - human solid tumors: 1
# - cytological experiments: 1
# - MPTP-induced PD mouse model: 1
# - single-cell high-plex cytometric imaging: 1
# - patient tumor explants: 1
# - Mice Behavior: 1
# - genome-wide CRISPR/Cas9 screen: 1
# - histopathological slides: 1
# - gene expression analyses: 1
# - Xenium-based spatial transcriptomics: 1
# - plasma proteomics: 1
# - GIS spatial analysis: 1
# - population sampling survey data: 1
# - census data: 1
# - GeoMx: 1
# - Real-time reverse transcription PCR: 1
# - Cell Counting Kit 8 (CCK8) assay: 1
# - digital spatial profiler: 1
# - endothelial monolayers: 1
# - 3D spheroids: 1
# - single-cell transcriptome analysis: 1
# - single-nuclei transcriptome analysis: 1
# - circulating biomarkers: 1
# - serum samples: 1
# - AI-assisted image analysis: 1
# - Bulk RNA-seq: 1
# - single nucleus gene expression: 1
# - urine adenine/creatinine ratio: 1
# - heart adenine and MTAP gene expression: 1
# - PD-L1 immunohistochemistry: 1
# - multiplex cytokine analysis: 1
# - aqueous-based tissue-clearing: 1
# - serum proteomic analyses: 1
# - multiplex cytokine and chemokine assays: 1
# - GeoMx Digital Spatial Profiler: 1
# - data-independent acquisition proteomics: 1
# - multiplexed quantitative immunofluorescence: 1
# - TCGA dataset: 1
# - METABRIC dataset: 1
# - in vitro model system: 1
# - ex vivo human tissue models: 1
# - bulk transcriptomic datasets: 1
# - single-cell transcriptomic datasets: 1
# - multi-fluorescence staining: 1
# - single-nuclei dataset: 1
# - fluorescent multiplex immunohistochemistry: 1
# - immunotherapy cohort data: 1
# - Landsat-OLI data: 1
# - Sentinel-MSI data: 1
# - field soil survey data: 1
# - diffusion magnetic resonance imaging: 1
# - Culture Media, Conditioned: 1
# - Extracellular Vesicles: 1
# - bioluminescence: 1
# - Bronchoalveolar lavage fluid analysis: 1
# - Multiplex cytokine analysis: 1
# - Hydroxyproline assay: 1
# - Immunohistochemical staining: 1
# - Quantitative polymerase chain reaction: 1
# - human cell culture models: 1
# - tomo-seq: 1
# - digital spatial RNA profiling: 1
# - cell line-derived tumours: 1
# - single-cell transcriptomic sequencing: 1
# - nuclei isolation methods: 1
# - formalin-fixed paraffin-embedded (FFPE) biopsies: 1
# - ex vivo staining: 1
# - in situ staining: 1
# - histological sections: 1
# - multi-region proteomics: 1
# - 10X Genomics Visium spatial transcriptomics: 1
# - single-cell-RNA-sequencing: 1
# - spatial-enhanced-resolution-omics-sequencing: 1
# - humanized mouse model: 1
# - CT phenotypes: 1
# - morphological analysis: 1
# - bioassays: 1
# - insect genomes: 1
# - single-cell expression data: 1
# - postmortem cortical tissue samples: 1
# - ToF-SIMS: 1
# - gastrointestinal tract analysis: 1
# - stable isotope analysis: 1
# - FT-IR spectroscopy: 1
# - single-nucleus chromatin accessibility: 1
# - Imaging Mass Cytometry (IMC): 1
# - transgenic mouse models: 1
# - population transcriptome sequencing: 1
# - whole chloroplast genomes: 1
# - mitochondrial DNA markers: 1
# - peripheral blood mononuclear cells (PBMCs): 1
# - sera: 1
# - lineage-tracing: 1
# - advanced imaging: 1
# - ATOH1 DNA binding: 1
# - Western Blot: 1
# - plaque staining: 1
# - immuno-staining: 1
# - sphere formation assay: 1
# - extreme limiting dilution: 1
# - Mass spectrometry: 1
# - RNA-sequencing detection: 1
# - qRT-RNA: 1
# - Mice: 1
# - Raman spectroscopy: 1
# - cerebral organoids: 1
# - induced pluripotent stem cells: 1
# - UPLC-Orbitrap Fusion MS: 1
# - molecular network analysis: 1
# - spatial RNA-sequencing: 1
# - formal-fixed paraffin-embedded immunohistochemical stainings: 1
# - single-nucleus multi-omics: 1
# - Visium spatial transcriptome: 1
# - MALDI-TOF-MSI: 1
# - network pharmacology: 1
# - molecular docking: 1
# - AP-MALDI-MSI: 1
# - single-cell spatial-RNA expression: 1
# - single-nuclear spatial-RNA expression: 1
# - spot-level spatial-RNA expression (Visium): 1
# - single-cell resolution spatial-RNA expression (CosMx): 1
# - single-nuclear open chromatin: 1
# - whole-transcriptome profiling: 1
# - spatial proteomics profiling: 1
# - genomic profiling: 1
# - single-cell profiling: 1
# - quantitative FISH: 1
# - multicolor immunofluorescence: 1
# - Diffusion Tensor Imaging: 1
# - NODDI: 1
# - gene deletion screen: 1
# - protein localisation: 1
# - transcriptome analysis: 1
# - SDS-PAGE: 1
# - nano-LC MS/MS: 1
# - bulk transcriptomic data: 1
# - in vivo single-cell transcriptomic data: 1
# - in vivo murine model: 1
# - stiffness measurement: 1
# - secretome: 1
# - tissue transplantation: 1
# - thyroid tissue histology: 1
# - Immunocytochemistry: 1
# - in situ proximity labeling: 1
# - genetic interaction studies: 1
# - quantitative partner matching assays: 1
# - single-axon resolution imaging: 1
# - transgenic approaches: 1
# - Notifiable Diseases Information System (SINAN): 1
# - species distribution modelling: 1
# - land-use/land-cover change data: 1
# - climate change scenarios: 1
# - Demographic and Health Surveys data: 1
# - phospho-SMAD1/5/8 immunohistochemistry: 1
# - leaf phenotype comparison: 1
# - DNA barcoding: 1
# - leaf anatomy: 1
# - phylogenetic analysis: 1
# - in situ hybridization chain reaction (HCR): 1
# - microarray-based spatial transcriptomic analyses: 1
# - proteomic: 1
# - lipidomic: 1
# - histological assessment: 1
# - Banff classification system: 1
# - epithelial desquamation: 1
# - genetic inhibition: 1
# - in vitro: 1
# - in vivo: 1
# - ex vivo skin explant tissue: 1
# - spatial variation of vegetation cover: 1
# - UHPLC-Q exactive orbitrap-HRMS: 1
# - rat plasma: 1
# - rat serum: 1
# - kidney tissue homogenate: 1
# - in situ whole transcriptomics: 1
# - 36-plex immunofluorescence imaging: 1
# - CUT&RUN: 1
# - hair cortisol: 1
# - single-cell RNA-Sequence: 1
# - GTEx: 1
# - Human Protein Atlas: 1
# - asmFISH: 1
# - functional genomics screening: 1
# - global chromatin mapping: 1
# - CRISPR screening: 1
# - in vivo studies in mice: 1
# - quantitative mass spectrometry-based proteomics: 1
# - mRNA translation: 1
# - biochemical analysis: 1
# - Nanostring nCounter® glial profiling: 1
# - neuroinflammation gene panels: 1
# - insulin-producing β cells: 1
# - human islets: 1
# - T1D-susceptible mice: 1
# - Single-cell RNA-Seq: 1
# - EndoC-βH1 human β cells: 1
# - TCGA multi-omics analysis: 1
# - in vitro experimental validation: 1
# - electrophysiology: 1
# - Exosomes: 1
# - peripheral blood T cells: 1
# - Genome-Wide Association Study (GWAS): 1
# - in vitro validation: 1
# - in vivo validation: 1
# - multi-ome: 1
# - cell-free RNA (cfRNA): 1
# - biochemical: 1
# - hematology: 1
# - single-cell chromatin accessibility: 1
# - spatial data of patient locations: 1
# - sociodemographic data: 1
# - meteorological data: 1
# - remote sensing: 1
# - in-situ BOD5 data: 1
# - multiplex immunostaining: 1
# - spatial transcriptome profiling: 1
# - glucose uptake experiments: 1
# - genetically engineered mouse models: 1
# - RNA velocity: 1
# - quantitative fluorescence-based assays: 1
# - multiomic analyses: 1
# - population genetics: 1
# - Sirius red staining: 1
# - wound healing assays: 1
# - transwell assays: 1
# - CCK8 assay: 1
# - fluorescence in situ hybridization: 1
# - 3'-single-cell RNA-sequencing: 1
# - Cellular Indexing of Transcriptomes and Epitopes by sequencing (CITE-seq): 1
# - 5'-V(D)J single-cell RNA-sequencing: 1
# - paired blood/spleen samples: 1
# - clinical datasets: 1
# - CosMx: 1
# - spatial transcriptomics RNA sequencing: 1
# - imaging-based techniques: 1
# - label-free reflectance imaging: 1
# - human ovarian pathology: 1
# - clinical biopsy data: 1
# - RNA transcripts: 1
# - ex vivo human psoriatic lesions: 1
# - murine model of skin inflammation: 1
# - whole transcriptome: 1
# - lipid profiles: 1
# - archival human cardiac tissue samples: 1
# - high-plex spatial protein analysis: 1
# - Matrix-Assisted Laser Desorption/Ionization Mass Spectrometry Imaging (MSI): 1
# - pluripotent stem cells: 1
# - cerebrospinal fluid (CSF): 1
# - brain parenchyma: 1
# - bulk tumors: 1
# - multiplexed single-cell technologies: 1
# - single nucleus RNA sequencing: 1
# - Laser Microdissection (LMD): 1
# - liquid chromatography–mass spectrometry: 1
# - vascular contraction testing: 1
# - proteomic imaging: 1
# - hematopoietic cells: 1
# - non-hematopoietic cells: 1
# - long-read sequencing: 1
# - short-read sequencing: 1
# - exome data: 1
# - primary patient-derived corneal endothelial cells (CECs): 1
# - single-nucleus RNA-sequencing: 1
# - histological staining: 1
# - Hematoxylin and eosin staining: 1
# - secondary data from Notifiable Diseases Information System (SINAN): 1
# - single-cell ribonucleic acid-sequencing: 1
# - in vitro coculture of CC cells with macrophages: 1
# - single cell RNA-Seq: 1
# - single-cell analyses: 1
# - quantitative immunostaining: 1
# - xenograft tumors: 1
# - CRISPR datasets: 1
# - multiplexed quantitative immunofluorescence (QIF): 1
# - flow cytometric analysis: 1
# - gene-targeted mice: 1
# - blocking antibody studies: 1
# - human tumor samples: 1
# - label-free proteomics: 1
# - data-independent LC-MS/MS: 1
# - Immunofluorescence imaging: 1
# - liver-specific transcriptomics: 1
# - single cell RNA sequencing (scRNA-seq): 1
# - cytokine analyses: 1
# - bulk analyses: 1
# - ex vivo electrophysiology: 1
# - xenograft model antitumor assays: 1
# - human Hirschsprung's disease gut tissue: 1
# - formalin-fixed, paraffin-embedded tissues: 1
# - public datasets (GEO, TCGA): 1
# - single-cell electrophysiology: 1
# - two-photon imaging: 1
# - microRNA: 1
# - methylome: 1
# - human APAP explant liver data: 1
# - high-throughput spatial analysis: 1
# - chromatin accessibility landscapes: 1
# - single-cell mapping of somatic alterations: 1
# - morphological imaging: 1
# - Mass Spectrometry Imaging (MSI): 1
# - fluorescence imaging: 1
# - label free proteomics: 1
# - laser capture microdissection (LMD): 1
# - spatial metallomics: 1
# - histopathological damage: 1
# - microstructural changes: 1
# - in vivo live imaging: 1
# - photo-activation-guided single-cell RNA sequencing: 1
# - CosMx single molecule imaging: 1
# - multicolor flow cytometry: 1
# - functional studies: 1
# - bulk tissue transcriptome data: 1
# - spatial analysis: 1
# - in vitro immuno-oncology platform: 1
# - functional assays: 1
# - single-nucleus multiomic (gene expression): 1
# - single-nucleus multiomic (chromatin accessibility): 1
# - stomach content analysis: 1
# - carbon and nitrogen stable isotope analysis: 1
# - human cortex: 1
# - genetic fate-mapping models: 1
# - spatial imaging mass cytometry: 1
# - RNA detection: 1
# - Ex vivo experiments: 1
# - SHARE-seq: 1
# - in vitro co-culture system: 1
# - immunohistochemistry analysis: 1
# - histological images: 1
# - DNA replication: 1
# - GC-MS: 1
# - genomic single nucleotide polymorphism sequencing: 1
# - multiplexed cytokines assays: 1
# - chromatin immunoprecipitation assays: 1
# - KPC mice: 1
# - CD45.1+ BALB/C nude mice: 1
# - CD34+ humanized mice: 1
# - tumor samples: 1
# - quantitative imaging: 1
# - bulk ATAC-sequence: 1
# - single-cell transcriptomic analysis: 1
# - occurrence data: 1
# - carbon emissions data: 1
# - in vivo lung perfusion (IVLP): 1
# - solid-phase microextraction (SPME) microprobes: 1
# - global metabolite profiling: 1
# - single nuclei RNA-sequencing: 1
# - RNASCOPE: 1
# - immunostaining analysis: 1
# - GeoMx Digital Spatial Profiling (DSP): 1
# - multiplexed fluorescent in situ hybridization: 1
# - RNASeq: 1
# - NanoString GeoMx® spatial transcriptomics: 1
# - intravital microscopy: 1
# - RNA microarray: 1
# - multiplexed immunolabeling: 1
# - spatial multi-omics: 1
# - single cell analysis: 1
# - RNA-SEQ: 1
# - Nanostring nCounter: 1
# - multiparametric flow cytometry: 1
# - spectral laboratory data: 1
# - spectral field data: 1
# - manganese-enhanced magnetic resonance imaging (MEMRI): 1
# - TurboID: 1
# - single-molecule spatial transcriptomics: 1
# - immunohistochemistry staining: 1
# - genome-wide association studies: 1
# - Visium CytAssist spatial transcriptomic (ST) assays: 1
# - DSP: 1
# - DESI-MS imaging: 1
# - epigenome: 1
# - immune repertoire sequencing: 1
# - non-targeted metabolomics: 1
# - targeted mass spectrometry: 1
# - quantitative RT-qPCR: 1
# - FFPE tissue sections: 1
# - imaging mass spectrometry: 1
# - digital spatial profiling (DSP): 1
# - Olink targeted proteomics: 1
# - sc/snRNA-seq: 1
# - reverse phase protein arrays: 1
# - PET imaging: 1
# - HPLC: 1
# - SEM: 1
# - EDS: 1
# - FT-IR: 1
# - UPLC-Q-TOF-MS/MS: 1
# - gas chromatography-mass spectrometry: 1
# - Seahorse live-cell metabolic analysis: 1
# - spatial-transcriptomics: 1
# - 3D models: 1
# - biopsy: 1
# - multiplexed immunostainings: 1
# - cell differentiation assays: 1
# - invasion assays: 1
# - MALDI-IMS: 1
# - Nanostring GeoMx DSP: 1
# - Single-Cell Gene Expression Analysis: 1
# - high-resolution whole-embryo imaging: 1
# - single-cell genomics: 1
# - whole-exome genomic analysis: 1
# - DTI: 1
# - scRNA: 1
# - RNA-ISH: 1
# - Slide-seq: 1
# - GeoMx digital spatial profiling: 1
# - CosMx spatial molecular imaging: 1
# - Visium spatial gene expression: 1
# - clinical data: 1
# - medical images: 1
# - NanoString: 1
# - imaging mass-cytometry: 1
# - bulk tissue sequencing: 1
# - LC/MS: 1
# - ST: 1
# - Immunofluorescence: 1
# - CyCIF: 1
# - confocal microscopy: 1
# - Hi-C: 1
# - immune imaging: 1
# - high-dimensional flow cytometry: 1
# - single cell chromatin accessibility: 1
# - 16S rRNA gene sequencing: 1
# - RNA in situ hybridization: 1
# - immunohistochemical: 1
# - immunofluorescent staining: 1
# - real-time qPCR: 1
# - mitochondrial DNA-based lineage tracing: 1
# - single-molecule array: 1
# - microglia/axon co-cultures: 1
# - RNA profiling in situ hybridization: 1
# - MALDI-TOF MS: 1
# - immunoproteomics: 1
# - ubiquitinome: 1
# - single-cell ATAC-seq: 1
# - electronical RNA in situ hybridization: 1
# - time-lapse microscopy: 1
# - super-resolution imaging: 1
# - single-nucleus RNAseq: 1
# - FFPE sections: 1
# - single-cell gene expression: 1
# - epitope mapping: 1

# %% [markdown]
# ATTENTION! This needs curation. As several are not methods or are just written in different ways.

# %%
print("\n--- Biological Context for Application Papers ---")

# Check if the 'biological_context' column exists
if 'biological_context' in application_papers_df.columns:
    # Count how many papers have a non-empty biological_context
    # .dropna() removes NaN (missing values)
    # .astype(bool) converts non-empty strings to True, empty strings to False
    # .sum() counts the True values
    num_with_context = application_papers_df['biological_context'].dropna().astype(bool).sum()
    num_without_context = len(application_papers_df) - num_with_context

    print(f"Total application papers: {len(application_papers_df)}")
    print(f"Papers with 'biological_context' provided: {num_with_context}")
    print(f"Papers without 'biological_context' provided: {num_without_context}")
    if len(application_papers_df) > 0:
        print(f"Percentage with context: {num_with_context / len(application_papers_df):.2%}")
        print(f"Percentage without context: {num_without_context / len(application_papers_df):.2%}")

    # Display some example biological contexts (first few non-empty ones)
    print("\nExample 'biological_context' entries (first 5 non-empty):")
    # Filter for non-empty contexts, drop duplicates for unique examples, and take head
    examples = application_papers_df[application_papers_df['biological_context'].astype(bool)]['biological_context'].drop_duplicates().head(5)
    if not examples.empty:
        for i, context in enumerate(examples):
            print(f"{i+1}. {context}")
    else:
        print("No non-empty 'biological_context' entries found in application papers.")

else:
    print("'biological_context' column not found in the DataFrame. Please check column names.")
# Out:
# --- Biological Context for Application Papers ---
# Total application papers: 1505
# Papers with 'biological_context' provided: 1505
# Papers without 'biological_context' provided: 0
# Percentage with context: 100.00%
# Percentage without context: 0.00%
#
# Example 'biological_context' entries (first 5 non-empty):
# 1. Colorectal cancer
# 2. Breast cancer progression (DCIS to IBC)
# 3. Human kidney diseases (collapsing glomerulopathy, crescentic glomerulonephritis) and mouse models of podocyte dysfunction
# 4. Primary sclerosing cholangitis and liver disease
# 5. Rheumatoid Arthritis (RA) synovium

# %%
if not application_papers_df.empty:
    if 'biological_context' in application_papers_df.columns:
        # Get value counts for the 'biological_context' column
        # .fillna('None Provided') ensures that missing values (NaN) are also counted as a category
        biological_context_counts = application_papers_df['biological_context'].fillna('None Provided').value_counts()

        if not biological_context_counts.empty:
            print("Counts of each unique 'biological_context' entry:")
            # .to_string() is used to ensure all rows are printed without truncation
            print(biological_context_counts.to_string())
            print(f"\nTotal unique biological contexts (including 'None Provided'): {len(biological_context_counts)}")
        else:
            print("No 'biological_context' entries found or processed for application papers (after filtering).")
    else:
        print("'biological_context' column not found in the application papers DataFrame. Please check column names.")
else:
    print("The application papers DataFrame is empty. Cannot generate biological context counts.")
# Out:
# Counts of each unique 'biological_context' entry:
# biological_context
# Alzheimer's disease                                                                                                                                                                                                                                                                 29
# Hepatocellular carcinoma (HCC)                                                                                                                                                                                                                                                      29
# Colorectal cancer                                                                                                                                                                                                                                                                   26
# Breast cancer                                                                                                                                                                                                                                                                       26
# N/A                                                                                                                                                                                                                                                                                 22
# Pancreatic cancer                                                                                                                                                                                                                                                                   19
# Prostate cancer                                                                                                                                                                                                                                                                     12
# Lung adenocarcinoma                                                                                                                                                                                                                                                                 11
# Hepatocellular carcinoma                                                                                                                                                                                                                                                            10
# Pancreatic ductal adenocarcinoma (PDAC)                                                                                                                                                                                                                                              9
# Glioblastoma                                                                                                                                                                                                                                                                         8
# Glioma                                                                                                                                                                                                                                                                               8
# Gastric cancer                                                                                                                                                                                                                                                                       7
# Mouse brain                                                                                                                                                                                                                                                                          6
# Head and neck squamous cell carcinoma (HNSCC)                                                                                                                                                                                                                                        6
# Non-small cell lung cancer (NSCLC)                                                                                                                                                                                                                                                   5
# Glioblastoma (GBM)                                                                                                                                                                                                                                                                   4
# Head and Neck Squamous Cell Carcinoma (HNSCC)                                                                                                                                                                                                                                        4
# Hepatocellular Carcinoma (HCC)                                                                                                                                                                                                                                                       4
# Lung adenocarcinoma (LUAD)                                                                                                                                                                                                                                                           4
# Melanoma                                                                                                                                                                                                                                                                             3
# Cervical squamous cell carcinoma                                                                                                                                                                                                                                                     3
# High-grade serous ovarian cancer (HGSOC)                                                                                                                                                                                                                                             3
# Healthy human kidney                                                                                                                                                                                                                                                                 3
# Parkinson's disease                                                                                                                                                                                                                                                                  3
# Psoriasis                                                                                                                                                                                                                                                                            3
# Diffuse large B-cell lymphoma (DLBCL)                                                                                                                                                                                                                                                3
# Ulcerative colitis                                                                                                                                                                                                                                                                   3
# Metabolic dysfunction-associated steatotic liver disease (MASLD)                                                                                                                                                                                                                     3
# Colorectal cancer (CRC)                                                                                                                                                                                                                                                              3
# Hepatoblastoma                                                                                                                                                                                                                                                                       3
# Spinal cord injury                                                                                                                                                                                                                                                                   3
# Clear cell renal cell carcinoma (ccRCC)                                                                                                                                                                                                                                              3
# Triple-negative breast cancer                                                                                                                                                                                                                                                        3
# High-grade serous ovarian carcinoma (HGSOC)                                                                                                                                                                                                                                          3
# Cervical cancer                                                                                                                                                                                                                                                                      3
# Medulloblastoma                                                                                                                                                                                                                                                                      3
# Mouse brain development                                                                                                                                                                                                                                                              3
# prostate cancer                                                                                                                                                                                                                                                                      3
# Colorectal cancer liver metastasis                                                                                                                                                                                                                                                   2
# Acetaminophen-induced liver injury                                                                                                                                                                                                                                                   2
# Maize kernel development                                                                                                                                                                                                                                                             2
# Atherosclerosis                                                                                                                                                                                                                                                                      2
# Papillary thyroid carcinoma                                                                                                                                                                                                                                                          2
# Thyroid cancer progression                                                                                                                                                                                                                                                           2
# Human fetal cortex development                                                                                                                                                                                                                                                       2
# Rheumatoid arthritis                                                                                                                                                                                                                                                                 2
# Liver cancer                                                                                                                                                                                                                                                                         2
# Endometriosis                                                                                                                                                                                                                                                                        2
# Muscle-invasive bladder cancer (MIBC)                                                                                                                                                                                                                                                2
# Endometriotic lesions                                                                                                                                                                                                                                                                2
# Triple-negative breast cancer (TNBC)                                                                                                                                                                                                                                                 2
# Knee osteoarthritis                                                                                                                                                                                                                                                                  2
# Hidradenitis suppurativa                                                                                                                                                                                                                                                             2
# Pituitary neuroendocrine tumors (PitNETs)                                                                                                                                                                                                                                            2
# Non-small cell lung cancer                                                                                                                                                                                                                                                           2
# Neuroblastoma                                                                                                                                                                                                                                                                        2
# Esophageal squamous cell carcinoma (ESCC)                                                                                                                                                                                                                                            2
# childhood-onset lupus nephritis (cLN)                                                                                                                                                                                                                                                2
# Oral squamous cell carcinoma                                                                                                                                                                                                                                                         2
# Human skin                                                                                                                                                                                                                                                                           2
# Skin wound healing                                                                                                                                                                                                                                                                   2
# Renal cell carcinoma                                                                                                                                                                                                                                                                 2
# Ovarian cancer                                                                                                                                                                                                                                                                       2
# Small cell lung cancer                                                                                                                                                                                                                                                               2
# Colon cancer                                                                                                                                                                                                                                                                         2
# Pulmonary arterial hypertension (PAH)                                                                                                                                                                                                                                                2
# Cholangiocarcinoma                                                                                                                                                                                                                                                                   2
# Abdominal aortic aneurysm (AAA)                                                                                                                                                                                                                                                      2
# Melanoma leptomeningeal disease (LMD)                                                                                                                                                                                                                                                2
# Ovarian Cancer                                                                                                                                                                                                                                                                       2
# Multiple sclerosis                                                                                                                                                                                                                                                                   2
# squamous epithelia and squamous cell carcinoma                                                                                                                                                                                                                                       2
# Intrahepatic cholangiocarcinoma (iCCA)                                                                                                                                                                                                                                               2
# clear cell renal cell carcinoma (ccRCC)                                                                                                                                                                                                                                              2
# Bladder cancer                                                                                                                                                                                                                                                                       2
# Muscle-invasive bladder cancer                                                                                                                                                                                                                                                       2
# Breast cancer lung metastasis                                                                                                                                                                                                                                                        2
# Multiple Sclerosis                                                                                                                                                                                                                                                                   2
# Hepatocellular carcinoma (HCC) tumor microenvironment                                                                                                                                                                                                                                2
# Mycobacterium tuberculosis infection in mouse lungs                                                                                                                                                                                                                                  2
# Mouse lung development                                                                                                                                                                                                                                                               2
# Intrahepatic cholangiocarcinoma (ICC)                                                                                                                                                                                                                                                2
# Human cerebellar development                                                                                                                                                                                                                                                         2
# Breast cancer metastasis                                                                                                                                                                                                                                                             2
# Chordoma                                                                                                                                                                                                                                                                             2
# Osteosarcoma lung metastasis                                                                                                                                                                                                                                                         2
# Human fetal lung development                                                                                                                                                                                                                                                         1
# Silk glands of mulberry silkworms during the final larval stage                                                                                                                                                                                                                      1
# Gestational syphilis in Brazil                                                                                                                                                                                                                                                       1
# Glioblastoma microenvironment                                                                                                                                                                                                                                                        1
# Clear Cell Renal Cell Carcinoma (ccRCC)                                                                                                                                                                                                                                              1
# Drosophila brain development, specifically synaptic partner matching in the olfactory circuit                                                                                                                                                                                        1
# Autoimmune thyroid diseases (Graves' disease, Hashimoto's thyroiditis)                                                                                                                                                                                                               1
# Mantle Cell Lymphoma                                                                                                                                                                                                                                                                 1
# Neurodegenerative diseases (e.g., Parkinson's disease)                                                                                                                                                                                                                               1
# Myometrial remodeling during term pregnancy                                                                                                                                                                                                                                          1
# Mouse brain aging and drug effects                                                                                                                                                                                                                                                   1
# colorectal cancer liver metastases                                                                                                                                                                                                                                                   1
# Tick-bitten skin                                                                                                                                                                                                                                                                     1
# Fetal liver and adult bone marrow hematopoietic stem cell niches                                                                                                                                                                                                                     1
# Offspring brain development under high maternal folic acid supplementation                                                                                                                                                                                                           1
# Mouse brain aging and rejuvenation                                                                                                                                                                                                                                                   1
# IgG4-related disease in submandibular gland                                                                                                                                                                                                                                          1
# Anti-inflammatory mechanism of coumarins in Peucedanum decursivum root                                                                                                                                                                                                               1
# Imipramine treated wild-type mice brains                                                                                                                                                                                                                                             1
# West Nile Virus (WNV) encephalitis in mice, focusing on microglial phenotype and neuroinflammation during aging and infection.                                                                                                                                                       1
# Lymph node-positive breast carcinoma                                                                                                                                                                                                                                                 1
# Merkel cell carcinoma (MCC)                                                                                                                                                                                                                                                          1
# Merkel cell carcinoma with neuroblastic components                                                                                                                                                                                                                                   1
# Human kidney diseases (diabetic and hypertensive)                                                                                                                                                                                                                                    1
# Endemic vascular flora of Peloponnese, Greece                                                                                                                                                                                                                                        1
# Late-onset Pompe disease (LOPD) muscle                                                                                                                                                                                                                                               1
# Human dorsal striatum (caudate nucleus and putamen) interneuron diversity                                                                                                                                                                                                            1
# Diabetic kidney disease (DKD)                                                                                                                                                                                                                                                        1
# Developing mouse brain                                                                                                                                                                                                                                                               1
# Leishmania parasitism                                                                                                                                                                                                                                                                1
# Gastric mixed adeno-neuroendocrine carcinoma (MANEC)                                                                                                                                                                                                                                 1
# Mouse spinal cord injury                                                                                                                                                                                                                                                             1
# Patients with end-stage kidney disease (ESKD) undergoing predilution online hemodiafiltration                                                                                                                                                                                        1
# Gastric cancer brain metastasis                                                                                                                                                                                                                                                      1
# Non-small-cell lung cancer (NSCLC)                                                                                                                                                                                                                                                   1
# Human blood vessels                                                                                                                                                                                                                                                                  1
# ER+HER2- Breast Cancer                                                                                                                                                                                                                                                               1
# Cortical development in ferrets, focusing on lissencephaly                                                                                                                                                                                                                           1
# Melanoma therapy resistance                                                                                                                                                                                                                                                          1
# Inguinal white adipose tissue adaptations to exercise training and cold exposure                                                                                                                                                                                                     1
# Head and Neck Cancer (HNC) tumor microenvironment                                                                                                                                                                                                                                    1
# Psoriasis epidermal cells                                                                                                                                                                                                                                                            1
# HIV and Tuberculosis co-infection in the lung                                                                                                                                                                                                                                        1
# Malaria risk prediction in the Republic of Korea                                                                                                                                                                                                                                     1
# The study investigates the impact of spaceflight on the mouse brain, specifically focusing on neurogenesis, synaptogenesis, synaptic transmission, astrocyte activation, and immune dysfunction.                                                                                     1
# Spaceflight effects on astronaut immune system                                                                                                                                                                                                                                       1
# Nephropathology, specifically focusing on renal tissue and kidney diseases.                                                                                                                                                                                                          1
# Prostate cancer (overall, aggressive, and early onset)                                                                                                                                                                                                                               1
# Psoriasis and Atopic Dermatitis                                                                                                                                                                                                                                                      1
# Halo nevus                                                                                                                                                                                                                                                                           1
# Embryonic mouse diaphragm development                                                                                                                                                                                                                                                1
# Brain tissue response to implanted electrodes in rat motor cortex                                                                                                                                                                                                                    1
# Postoperative cognitive dysfunction (POCD) after cardiopulmonary bypass (CPB) in rats                                                                                                                                                                                                1
# Autoimmune diabetes (Type 1 Diabetes)                                                                                                                                                                                                                                                1
# Traumatic brain injury (TBI) effects on the adult hippocampus of male mice                                                                                                                                                                                                           1
# Cancer-related cognitive impairment (CRCI) induced by extracranial radiation therapy (ECRT)                                                                                                                                                                                          1
# Left Ventricular Hypertrophy in Mice                                                                                                                                                                                                                                                 1
# Autoimmune type 1 diabetes (T1D) in mice and human islets                                                                                                                                                                                                                            1
# Loeys-Dietz syndrome (LDS) mouse model and human aortic VSMCs                                                                                                                                                                                                                        1
# Oral squamous cell carcinoma (OSCC) progression                                                                                                                                                                                                                                      1
# Hormone receptor-positive breast carcinoma                                                                                                                                                                                                                                           1
# Gallbladder cancer (GBC) liver invasion                                                                                                                                                                                                                                              1
# Ovarian ovulation in mice                                                                                                                                                                                                                                                            1
# Splenic marginal zone lymphoma (SMZL)                                                                                                                                                                                                                                                1
# Placenta accreta spectrum disorders                                                                                                                                                                                                                                                  1
# Murine gut microbiota recovery after antibiotic perturbation                                                                                                                                                                                                                         1
# Humoral immunity and T follicular helper cell specialization under type-1 and type-2 immune responses                                                                                                                                                                                1
# Rice seed germination                                                                                                                                                                                                                                                                1
# Invasiveness and interspecific competition among gecko species in Japan.                                                                                                                                                                                                             1
# Kidney fibrosis following ischemia/reperfusion injury                                                                                                                                                                                                                                1
# Human kidney disease, including COVID-19, HIV, and APOL1 nephropathy                                                                                                                                                                                                                 1
# Human sebaceous gland differentiation and sebum production                                                                                                                                                                                                                           1
# Liver hepatocellular carcinoma (LIHC)                                                                                                                                                                                                                                                1
# Proliferative glomerulonephritis and lupus nephritis in mice and humans                                                                                                                                                                                                              1
# Granuloma annulare (GA) is an idiopathic condition characterized by granulomatous inflammation in the skin.                                                                                                                                                                          1
# Mammalian brain responses to antidepressant and probiotic treatments                                                                                                                                                                                                                 1
# Plasmodium infection in mice                                                                                                                                                                                                                                                         1
# Inflammatory muscle diseases (Inclusion Body Myositis and Immune-mediated Necrotizing Myopathy)                                                                                                                                                                                      1
# Glioblastoma multiforme (GBM)                                                                                                                                                                                                                                                        1
# Pancreatic inflammation and injury response modulated by EHMT2 gene inactivation in exocrine cells                                                                                                                                                                                   1
# Idiopathic Pulmonary Fibrosis (IPF) distal bronchioles                                                                                                                                                                                                                               1
# Invasive mucinous adenocarcinoma of the lung (IMA) and lung adenocarcinoma with signet ring cell features (SRCC)                                                                                                                                                                     1
# Stemona tuberosa Lour. (ST) and honey-fried Stemona tuberosa Lour. (HST)                                                                                                                                                                                                             1
# Gastric cancer and peritoneal metastases                                                                                                                                                                                                                                             1
# ...
# Ovarian and cervical cancers                                                                                                                                                                                                                                                         1
# Human primary untreated tumors across 10 cancer types, with a focus on bladder cancer for treatment sensitivity analysis.                                                                                                                                                            1
# Human craniofacial development                                                                                                                                                                                                                                                       1
# Human placenta and reproductive immunology                                                                                                                                                                                                                                           1
# Grapes (Vitis vinifera L.)                                                                                                                                                                                                                                                           1
# Tumor heterogeneity                                                                                                                                                                                                                                                                  1
# Tumors                                                                                                                                                                                                                                                                               1
# Salmonella infection in mice                                                                                                                                                                                                                                                         1
# Human lung cancer                                                                                                                                                                                                                                                                    1
# Hepatic lipid homeostasis                                                                                                                                                                                                                                                            1
# Myocardial Infarction in Rats                                                                                                                                                                                                                                                        1
# Post-stroke unilateral spatial neglect (USN)                                                                                                                                                                                                                                         1
# Biliary tract cancer                                                                                                                                                                                                                                                                 1
# Gastric cancer liver metastasis                                                                                                                                                                                                                                                      1
# Mouse model of hyperuricemia                                                                                                                                                                                                                                                         1
# Mouse spinal cord under neuropathic pain conditions                                                                                                                                                                                                                                  1
# Mouse forebrain neural stem cell niche under homeostatic and injury conditions                                                                                                                                                                                                       1
# Adrenal cells and aldosterone-producing adenomas (APAs)                                                                                                                                                                                                                              1
# Pancreatic cancer liver metastasis                                                                                                                                                                                                                                                   1
# Healthy human spinal cord                                                                                                                                                                                                                                                            1
# Aging wild-type and mutant mouse lung exposed to ozone                                                                                                                                                                                                                               1
# Neonatal mouse heart                                                                                                                                                                                                                                                                 1
# Equine dorsal root ganglia (DRG) in healthy adult horses, with potential application to spinal neurodegenerative conditions in horses.                                                                                                                                               1
# Mouse liver cell types and zonal distribution of drug-processing genes                                                                                                                                                                                                               1
# Mouse adult subventricular neural stem cell (NSC) niche                                                                                                                                                                                                                              1
# Rheumatoid Arthritis                                                                                                                                                                                                                                                                 1
# Infrapatellar fat pad during knee osteoarthritis                                                                                                                                                                                                                                     1
# spinal cord aging                                                                                                                                                                                                                                                                    1
# Viral infection, specifically in relation to immune response and potential fibrotic complications.                                                                                                                                                                                   1
# Breast angiosarcoma and head and neck angiosarcoma                                                                                                                                                                                                                                   1
# Fulminant viral myocarditis induced by Coxsackievirus B3 in mice                                                                                                                                                                                                                     1
# Lung squamous cell carcinoma                                                                                                                                                                                                                                                         1
# Skeletal muscle fibrosis, specifically in the context of muscular dystrophies and acute muscle injury                                                                                                                                                                                1
# Penile carcinoma                                                                                                                                                                                                                                                                     1
# Pan-cancer, Glioblastoma Multiforme (GBM)                                                                                                                                                                                                                                            1
# Human heart development during the first gestational trimester                                                                                                                                                                                                                       1
# Amyotrophic Lateral Sclerosis (ALS) in SOD1²ⁱ⁰ˢ mouse model                                                                                                                                                                                                                          1
# Serotonin transporter knockout rats, prefrontal cortex function, anxiety                                                                                                                                                                                                             1
# Pan-cancer examination of MAFF's role in tumor progression, prognosis, and immune landscape                                                                                                                                                                                          1
# Mouse gut                                                                                                                                                                                                                                                                            1
# Cerebral ischemia-reperfusion injury in mice                                                                                                                                                                                                                                         1
# Human skin infection with Haemophilus ducreyi                                                                                                                                                                                                                                        1
# Uterine metaplasia and infertility in mice                                                                                                                                                                                                                                           1
# Ovarian follicular development in sows and its impairment during lactational high weight loss, with mitigation by butyrate.                                                                                                                                                          1
# Liver damage, ductular reaction, and liver fibrosis                                                                                                                                                                                                                                  1
# skin wound healing and scar formation                                                                                                                                                                                                                                                1
# Wheat root apical meristems                                                                                                                                                                                                                                                          1
# Epidermal differentiation disorders (ichthyosis and palmoplantar keratoderma (PPK)) and progressive symmetric erythrokeratoderma (PSEK) phenotypes.                                                                                                                                  1
# Hepatoblastoma, pediatric liver cancer                                                                                                                                                                                                                                               1
# Pulmonary fibrosis, distal lung remodeling                                                                                                                                                                                                                                           1
# Keloids, Skin Fibrosis                                                                                                                                                                                                                                                               1
# Offspring lung growth and function following prenatal exposure to THC                                                                                                                                                                                                                1
# Lymphangioleiomyomatosis (LAM) lung disease                                                                                                                                                                                                                                          1
# Cerebral ischemia/reperfusion (I/R) injury in rats                                                                                                                                                                                                                                   1
# Non-small cell lung cancer (NSCLC) with mature tertiary lymphoid structures (mTLSs)                                                                                                                                                                                                  1
# Human hypothalamus                                                                                                                                                                                                                                                                   1
# Latent Mycobacterium tuberculosis infection in lymphatics                                                                                                                                                                                                                            1
#
# Total unique biological contexts (including 'None Provided'): 1190

# %%
print("\n--- Methodology Type Counts for 'method' papers ---")
method_papers = df_annotations[df_annotations['paper_type'] == 'method']
if not method_papers.empty:
    print(method_papers['methodology_type'].value_counts())
else:
    print("No 'method' papers found.")

# Example: Count occurrences of each data modality
print("\n--- Data Modalities Counts ---")
# For list columns, you need to "explode" them or use apply with Counter
all_modalities = Counter()
for modalities_list in df_annotations['data_modalities_used'].dropna():
    all_modalities.update(modalities_list)
print(all_modalities.most_common(10)) # Top 10 most common modalities
# Out:
# --- Methodology Type Counts for 'method' papers ---
# methodology_type
# algorithm            526
# pipeline             237
# framework            193
# tool                 193
# workflow              62
# other_methodology     43
# N/A                   10
# dataset                1
# method                 1
# Name: count, dtype: int64
#
# --- Data Modalities Counts ---
# [('spatial transcriptomics', 1927), ('histology images', 548), ('single-cell RNA sequencing', 296), ('spatial proteomics', 242), ('scRNA-seq', 173), ('single-cell transcriptomics', 156), ('snRNA-seq', 153), ('sequencing', 147), ('multiplexed imaging', 124), ('immunohistochemistry', 95)]
